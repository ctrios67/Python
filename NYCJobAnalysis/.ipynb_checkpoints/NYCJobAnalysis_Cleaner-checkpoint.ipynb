# %%
import pandas as pd
import datetime as dt

today = dt.datetime.today().strftime("%m/%d/%Y %H:%M:%S")
NYC = pd.read_json('https://data.cityofnewyork.us/resource/swhp-yxa4.json')

# %%
NYC.info()
NYC.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 25 columns):
# __of_positions               1000 non-null int64
# additional_information       1000 non-null object
# agency                       1000 non-null object
# business_title               1000 non-null object
# civil_service_title          1000 non-null object
# division_work_unit           1000 non-null object
# hours_shift                  1000 non-null object
# job_description              1000 non-null object
# job_id                       1000 non-null int64
# level                        1000 non-null object
# minimum_qual_requirements    998 non-null object
# post_until                   289 non-null object
# posting_date                 1000 non-null object
# posting_type                 1000 non-null object
# posting_updated              1000 non-null object
# preferred_skills             1000 non-null object
# process_date                 1000 non-null object
# residency_requirement        1000 non-null object
# salary_frequency             1000 non-null object
# salary_range_from            1000 non-null int64
# salary_range_to              1000 non-null int64
# title_code_no                1000 non-null object
# to_apply                     1000 non-null object
# work_location                1000 non-null object
# work_location_1              1000 non-null object
# dtypes: int64(4), object(21)
# memory usage: 203.1+ KB
#    __of_positions additional_information                          agency  \
# 0               1                            HRA/DEPT OF SOCIAL SERVICES
# 1               1                         HOUSING PRESERVATION & DVLPMNT
# 2               1                         HOUSING PRESERVATION & DVLPMNT
#
#                             business_title    civil_service_title  \
# 0  Community Resolution Services Associate  COMMUNITY COORDINATOR
# 1                        Project Associate  COMMUNITY COORDINATOR
# 2     Planner (Neighborhood Planning Unit)           CITY PLANNER
#
#              division_work_unit hours_shift  \
# 0       Constituent Services-NM
# 1  ONS - Community Partnerships
# 2                ONS - Planning
#
#                                      job_description  job_id level  \
# 0  The Office of Constituent Services (OCS) commu...  248000    00
# 1  The New York City Department of Housing Preser...  286557    00
# 2  Under the direction of the Director of Neighbo...  231851    01
#
#         ...                                          preferred_skills  \
# 0       ...
# 1       ...         â€¢\tA graduate degree in the field of public ...
# 2       ...         1.  Thorough knowledge of New York City govern...
#
#           process_date                              residency_requirement  \
# 0  04/25/2017 00:00:00  New York City residency is generally required ...
# 1  04/25/2017 00:00:00  New York City residency is generally required ...
# 2  04/25/2017 00:00:00  New York City residency is generally required ...
#
#   salary_frequency salary_range_from salary_range_to title_code_no  \
# 0           Annual             48895           56229         56058
# 1           Annual             60000           65000         56058
# 2           Annual             49897           72061         22122
#
#                       to_apply         work_location  work_location_1
# 0  Click ''APPLY NOW'' Button.  4 World Trade Center
# 1                 Apply Online       100 Gold Street  100 Gold Street
# 2                 Apply Online       100 Gold Street  100 Gold Street
#
# [3 rows x 25 columns]

# %% [markdown]
# # Cleaning the Data.

# %%
# Taking care of Nulls
NYC['minimum_qual_requirements'].fillna('Not Applicable', inplace=True)
NYC['post_until'].fillna(today, inplace=True)
NYC['post_until'] = pd.to_datetime(NYC['post_until'])
NYC['posting_date'] = pd.to_datetime(NYC['posting_date'])
NYC['process_date'] = pd.to_datetime(NYC['process_date'])


# There are "empty" columns still in the data, but not NULL, need to be taken care of.
NYC['additional_information'] # -> Some results are "empty", like in index 2
NYC['additional_information'][2] # -> is equal to ' '
add_info_mask = NYC['additional_information'] == ' '
NYC[add_info_mask] # 432 occurences of this
hours_shift_mask = NYC['hours_shift'] == ' '
NYC[hours_shift_mask] # 684 occurences
pref_skill_mask = NYC['preferred_skills'] == ' ' # 118 occurences
work_loc_1_mask = NYC['work_location_1'] == ' ' # 520 occurences
mask = [add_info_mask, hours_shift_mask, pref_skill_mask, work_loc_1_mask]

# Replace Nulls that we as viewer see, but that Pandas is unaware about.
NYC['additional_information'] = NYC['additional_information'].replace(to_replace=' ', value='Not Available.')
NYC['hours_shift'] = NYC['hours_shift'].replace(to_replace=' ', value='Not Available.')
NYC['preferred_skills'] = NYC['preferred_skills'].replace(to_replace=' ', value='Not Available.')
NYC['work_location_1'] = NYC['work_location_1'].replace(to_replace=' ', value='Not Available.')
NYC

# Seeing which objects I put as categorize as dtype category to conserve space/efficiency.
unique = {}
for col in NYC.columns:
    unique[col] = NYC[col].nunique()
#print(unique)

# Applying what I noticed from previous cell.
NYC['agency'] = NYC['agency'].astype('category')
NYC['level'] = NYC['level'].astype('category')
NYC['posting_type'] = NYC['posting_type'].astype('category')
NYC['salary_frequency'] = NYC['salary_frequency'].astype('category')

# Sort by index
NYC = NYC.set_index('agency')
NYC.sort_index(inplace=True)

# memory usage shrunk from 203.1 KB -> 168.5 KB, 17%
NYC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# CategoricalIndex: 1000 entries, ADMIN FOR CHILDREN'S SVCS to TEACHERS RETIREMENT SYSTEM
# Data columns (total 24 columns):
# __of_positions               1000 non-null int64
# additional_information       1000 non-null object
# business_title               1000 non-null object
# civil_service_title          1000 non-null object
# division_work_unit           1000 non-null object
# hours_shift                  1000 non-null object
# job_description              1000 non-null object
# job_id                       1000 non-null int64
# level                        1000 non-null category
# minimum_qual_requirements    1000 non-null object
# post_until                   1000 non-null datetime64[ns]
# posting_date                 1000 non-null datetime64[ns]
# posting_type                 1000 non-null category
# posting_updated              1000 non-null object
# preferred_skills             1000 non-null object
# process_date                 1000 non-null datetime64[ns]
# residency_requirement        1000 non-null object
# salary_frequency             1000 non-null category
# salary_range_from            1000 non-null int64
# salary_range_to              1000 non-null int64
# title_code_no                1000 non-null object
# to_apply                     1000 non-null object
# work_location                1000 non-null object
# work_location_1              1000 non-null object
# dtypes: category(3), datetime64[ns](3), int64(4), object(14)
# memory usage: 168.5+ KB

# %% [markdown]
# # Data Analysis

# %%
# Let's grab the Agency names and their available # of positions and visualize the agency with the highest positions.
num_pos = NYC[[0]]
grouping = num_pos.groupby(num_pos.index)
agency_pos_count = grouping.count().sort_values(by='__of_positions', ascending=False)
num_pos.info()
agency_pos_count
# Out:
# <class 'pandas.core.frame.DataFrame'>
# CategoricalIndex: 1000 entries, ADMIN FOR CHILDREN'S SVCS to TEACHERS RETIREMENT SYSTEM
# Data columns (total 1 columns):
# __of_positions    1000 non-null int64
# dtypes: int64(1)
# memory usage: 9.2 KB
#                                 __of_positions
# agency
# DEPT OF HEALTH/MENTAL HYGIENE              247
# DEPT OF ENVIRONMENT PROTECTION             122
# DEPARTMENT OF TRANSPORTATION                69
# DEPARTMENT OF FINANCE                       54
# DEPT OF INFO TECH & TELECOMM                47
# POLICE DEPARTMENT                           37
# DEPT OF DESIGN & CONSTRUCTION               36
# LAW DEPARTMENT                              26
# FIRE DEPARTMENT                             26
# DEPT OF PARKS & RECREATION                  25
# HOUSING PRESERVATION & DVLPMNT              24
# DEPARTMENT OF INVESTIGATION                 23
# DEPARTMENT OF BUSINESS SERV.                20
# ADMIN FOR CHILDREN'S SVCS                   19
# ADMIN TRIALS AND HEARINGS                   17
# HRA/DEPT OF SOCIAL SERVICES                 17
# NYC HOUSING AUTHORITY                       13
# DEPARTMENT OF BUILDINGS                     13
# DEPARTMENT OF CORRECTION                    12
# MAYORS OFFICE OF CONTRACT SVCS              12
# DEPT OF CITYWIDE ADMIN SVCS                 11
# TAXI & LIMOUSINE COMMISSION                 11
# DEPARTMENT OF SANITATION                    10
# OFFICE OF EMERGENCY MANAGEMENT               9
# NYC EMPLOYEES RETIREMENT SYS                 9
# OFFICE OF THE COMPTROLLER                    8
# TEACHERS RETIREMENT SYSTEM                   7
# DEPT OF YOUTH & COMM DEV SRVS                7
# DISTRICT ATTORNEY KINGS COUNTY               6
# DEPARTMENT OF CITY PLANNING                  6
# DISTRICT ATTORNEY RICHMOND COU               6
# DEPARTMENT FOR THE AGING                     5
# DEPT. OF HOMELESS SERVICES                   5
# CIVILIAN COMPLAINT REVIEW BD                 4
# FINANCIAL INFO SVCS AGENCY                   4
# CULTURAL AFFAIRS                             4
# HUMAN RIGHTS COMMISSION                      4
# BOARD OF CORRECTION                          3
# BUSINESS INTEGRITY COMMISSION                3
# CONSUMER AFFAIRS                             3
# DEPARTMENT OF PROBATION                      2
# OFFICE OF COLLECTIVE BARGAININ               2
# CONFLICTS OF INTEREST BOARD                  2
# OFF OF PAYROLL ADMINISTRATION                2
# EQUAL EMPLOY PRACTICES COMM                  1
# OFFICE OF MANAGEMENT & BUDGET                1
# MANHATTAN COMMUNITY BOARD #10                1
# DEPT OF RECORDS & INFO SERVICE               1
# PRESIDENT BOROUGH OF MANHATTAN               1
# TAX COMMISSION                               1
# LANDMARKS PRESERVATION COMM                  1
# NYC DEPT OF VETERANS' SERVICES               1

# %% [markdown]
# # Consolidating Hourly, Daily, and Annual Salaries to see Highest & Lowest Overall Pay

# %%
# Let's create a filter to see which agencies have the lowest salary offered
lowest_sal = NYC[['salary_frequency', 'salary_range_from']]
lowHourly = lowest_sal['salary_frequency'] == 'Hourly'
lowDaily = lowest_sal['salary_frequency'] == 'Daily'
lowAnnually = lowest_sal['salary_frequency'] == 'Annual'

# Let's create a filter to see which agencies have the highest salary offered
highest_sal = NYC[['salary_frequency', 'salary_range_to']]
hiHourly = highest_sal['salary_frequency'] == 'Hourly'
hiDaily = highest_sal['salary_frequency'] == 'Daily'
hiAnnually = highest_sal['salary_frequency'] == 'Annual'

# I'm taking an assumption of 37.5 hours/week based on most data being 35, or 40 hours.
def hourlyToAnnual(feed):
    return feed*37.5*52

# I'm taking a generic assumption that a daily worker works 5 days a week, every week.
def dailyToAnnual(feed):
    return feed*5*52

lowest_sal.info()
print()
highest_sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# CategoricalIndex: 1000 entries, ADMIN FOR CHILDREN'S SVCS to TEACHERS RETIREMENT SYSTEM
# Data columns (total 2 columns):
# salary_frequency     1000 non-null category
# salary_range_from    1000 non-null int64
# dtypes: category(1), int64(1)
# memory usage: 10.2 KB
#
# <class 'pandas.core.frame.DataFrame'>
# CategoricalIndex: 1000 entries, ADMIN FOR CHILDREN'S SVCS to TEACHERS RETIREMENT SYSTEM
# Data columns (total 2 columns):
# salary_frequency    1000 non-null category
# salary_range_to     1000 non-null int64
# dtypes: category(1), int64(1)
# memory usage: 10.2 KB

# %%
# Create a DataFrame with the lowest Salaries offered, sorted.
lowest_sal['Conversions'] = lowest_sal.loc[:, 'salary_range_from']
lowest_sal['Conversions'][lowHourly] = lowest_sal['Conversions'].apply(hourlyToAnnual)
lowest_sal['Conversions'][lowDaily] = lowest_sal['Conversions'].apply(dailyToAnnual)

lowest_sal = lowest_sal[['Conversions']]
low_group = lowest_sal.groupby(lowest_sal.index)
lowest_sal = low_group.min().sort_values(by = 'Conversions')
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py:4702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2881: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
lowest_sal.head(10)
# Out:
#                                 Conversions
# agency
# DISTRICT ATTORNEY RICHMOND COU            0
# OFFICE OF COLLECTIVE BARGAININ        17550
# ADMIN TRIALS AND HEARINGS             19500
# DEPT OF HEALTH/MENTAL HYGIENE         19500
# DEPT OF ENVIRONMENT PROTECTION        19500
# DEPARTMENT OF FINANCE                 19500
# TEACHERS RETIREMENT SYSTEM            21450
# POLICE DEPARTMENT                     21450
# DEPARTMENT OF BUILDINGS               21450
# DEPARTMENT OF PROBATION               21450

# %%
# Create a DataFrame with the highest Salaries offered, sorted.
highest_sal['Conversions'] = highest_sal.loc[:, 'salary_range_to']
highest_sal['Conversions'][hiHourly] = highest_sal['Conversions'].apply(hourlyToAnnual)
highest_sal['Conversions'][hiDaily] = highest_sal['Conversions'].apply(dailyToAnnual)

highest_sal = highest_sal[['Conversions']]
hi_group = highest_sal.groupby(highest_sal.index)
highest_sal = hi_group.min().sort_values(by = 'Conversions', ascending=False)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py:4702: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2881: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
highest_sal.head(10)
# Out:
#                                 Conversions
# agency
# OFFICE OF MANAGEMENT & BUDGET        106475
# CIVILIAN COMPLAINT REVIEW BD          90000
# FINANCIAL INFO SVCS AGENCY            87450
# EQUAL EMPLOY PRACTICES COMM           85029
# DEPT OF RECORDS & INFO SERVICE        81791
# NYC DEPT OF VETERANS' SERVICES        78177
# OFF OF PAYROLL ADMINISTRATION         72000
# DEPARTMENT OF CITY PLANNING           69807
# TAX COMMISSION                        69738
# ADMIN FOR CHILDREN'S SVCS             69252

# %% [markdown]
# # Visualizing Findings

# %%
from bokeh.charts import Bar, output_notebook, output_file, show
from bokeh.plotting import figure, output_notebook, output_file, show
from bokeh.models import ColumnDataSource, LabelSet

# %%
axes = lowest_sal['Conversions']
step = int(axes.max()/lowest_sal.index.nunique())
x_axis = (0, axes.max())
y_axis = list(lowest_sal.index)

p = figure(x_range = x_axis, 
           y_range = y_axis, 
           x_minor_ticks=step,
           y_axis_label = 'NYC Agencies',
           x_axis_label = 'Salaries')
h = axes.mean()
p.hbar(y= y_axis, height=0.5, right=axes)
output_notebook()
show(p, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fdce9294-0ee6-4e82-95c7-62c061e8b88a">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7abdf4f6-94ea-40cc-9bf2-70227ab23e7b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("7abdf4f6-94ea-40cc-9bf2-70227ab23e7b").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("6b689c03-de69-4643-85d1-ee7e8e30e3db", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7abdf4f6-94ea-40cc-9bf2-70227ab23e7b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7abdf4f6-94ea-40cc-9bf2-70227ab23e7b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"36b1adb4-cc34-4de0-984f-86c8c192b1c6":{"roots":{"references":[{"attributes":{"callback":null,"factors":["DISTRICT ATTORNEY RICHMOND COU","OFFICE OF COLLECTIVE BARGAININ","ADMIN TRIALS AND HEARINGS","DEPT OF HEALTH/MENTAL HYGIENE","DEPT OF ENVIRONMENT PROTECTION","DEPARTMENT OF FINANCE","TEACHERS RETIREMENT SYSTEM","POLICE DEPARTMENT","DEPARTMENT OF BUILDINGS","DEPARTMENT OF PROBATION","DEPT OF PARKS & RECREATION","DEPT OF INFO TECH & TELECOMM","DEPARTMENT OF SANITATION","LAW DEPARTMENT","DEPT OF YOUTH & COMM DEV SRVS","DEPARTMENT OF BUSINESS SERV.","NYC HOUSING AUTHORITY","DEPT OF DESIGN & CONSTRUCTION","NYC EMPLOYEES RETIREMENT SYS","MAYORS OFFICE OF CONTRACT SVCS","DEPARTMENT OF TRANSPORTATION","DEPT OF CITYWIDE ADMIN SVCS","MANHATTAN COMMUNITY BOARD #10","DEPARTMENT OF CORRECTION","BUSINESS INTEGRITY COMMISSION","HOUSING PRESERVATION & DVLPMNT","HRA/DEPT OF SOCIAL SERVICES","FIRE DEPARTMENT","DEPT. OF HOMELESS SERVICES","CULTURAL AFFAIRS","TAXI & LIMOUSINE COMMISSION","LANDMARKS PRESERVATION COMM","DEPARTMENT OF INVESTIGATION","DISTRICT ATTORNEY KINGS COUNTY","CONFLICTS OF INTEREST BOARD","HUMAN RIGHTS COMMISSION","BOARD OF CORRECTION","ADMIN FOR CHILDREN'S SVCS","OFFICE OF EMERGENCY MANAGEMENT","OFFICE OF THE COMPTROLLER","DEPARTMENT FOR THE AGING","NYC DEPT OF VETERANS' SERVICES","PRESIDENT BOROUGH OF MANHATTAN","OFF OF PAYROLL ADMINISTRATION","TAX COMMISSION","CONSUMER AFFAIRS","DEPT OF RECORDS & INFO SERVICE","CIVILIAN COMPLAINT REVIEW BD","DEPARTMENT OF CITY PLANNING","FINANCIAL INFO SVCS AGENCY","EQUAL EMPLOY PRACTICES COMM","OFFICE OF MANAGEMENT & BUDGET"]},"id":"6ad0620e-39c2-4455-90d6-fe6134f7dfba","type":"FactorRange"},{"attributes":{},"id":"fc1259ff-7d35-4e5c-a952-91b723c4dd3c","type":"CategoricalTickFormatter"},{"attributes":{"axis_label":"Salaries","formatter":{"id":"eb14742d-47a8-438a-813f-33bae0972561","type":"BasicTickFormatter"},"plot":{"id":"3113989a-c1aa-45f9-9b46-fa3d8c6b9359","subtype":"Figure","type":"Plot"},"ticker":{"id":"0c38ddac-b219-4369-8659-caa2cb676433","type":"BasicTicker"}},"id":"67161e29-b89e-41ff-aa96-3c6b88ede325","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"9a9de006-01c7-487d-8dcb-8ad0253d0216","type":"Title"},{"attributes":{"num_minor_ticks":2047},"id":"0c38ddac-b219-4369-8659-caa2cb676433","type":"BasicTicker"},{"attributes":{"axis_label":"NYC Agencies","formatter":{"id":"fc1259ff-7d35-4e5c-a952-91b723c4dd3c","type":"CategoricalTickFormatter"},"plot":{"id":"3113989a-c1aa-45f9-9b46-fa3d8c6b9359","subtype":"Figure","type":"Plot"},"ticker":{"id":"88a5d356-320e-46bd-87aa-2f4a442f5a52","type":"CategoricalTicker"}},"id":"d809ad37-06ee-4e86-a69b-15f552864dde","type":"CategoricalAxis"},{"attributes":{"plot":{"id":"3113989a-c1aa-45f9-9b46-fa3d8c6b9359","subtype":"Figure","type":"Plot"},"ticker":{"id":"0c38ddac-b219-4369-8659-caa2cb676433","type":"BasicTicker"}},"id":"9894e070-76bb-41cc-853b-32ab0214d5b9","type":"Grid"},{"attributes":{},"id":"88a5d356-320e-46bd-87aa-2f4a442f5a52","type":"CategoricalTicker"},{"attributes":{"dimension":1,"plot":{"id":"3113989a-c1aa-45f9-9b46-fa3d8c6b9359","subtype":"Figure","type":"Plot"},"ticker":{"id":"88a5d356-320e-46bd-87aa-2f4a442f5a52","type":"CategoricalTicker"}},"id":"14091347-8172-4c5d-be21-0fe9cac2aa04","type":"Grid"},{"attributes":{"data_source":{"id":"a32d3dc9-0784-4c8a-9916-831d6d296c75","type":"ColumnDataSource"},"glyph":{"id":"14406222-c138-4cbb-9fdd-33b7e2a8f6f8","type":"HBar"},"hover_glyph":null,"nonselection_glyph":{"id":"b725d9c1-36cb-447b-b332-6193d195a19e","type":"HBar"},"selection_glyph":null},"id":"b7719040-16c4-4a03-8489-7fdee340006d","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c096550c-877b-4 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[11]</strong>&gt;</code></p>

# %%
p_low = Bar(data=lowest_sal,
            values='Conversions',
            color='green',
            group=lowest_sal.index,
            title='Lowest Pay Offered by NYC Govt Agency',
            legend=False)

output_notebook()
show(p_low, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9351bc4a-8dd7-4595-9a01-8a1fa47c96ab">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="191cc2b3-5f03-4524-9ffc-b96d16567fa6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("191cc2b3-5f03-4524-9ffc-b96d16567fa6").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("af4b7761-e3ed-47e5-af4f-8040dc443195", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("191cc2b3-5f03-4524-9ffc-b96d16567fa6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '191cc2b3-5f03-4524-9ffc-b96d16567fa6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f4cfa782-fdc8-45d2-858c-d6c9ec7a54d5":{"roots":{"references":[{"attributes":{"axis_label":"Sum( Conversions )","formatter":{"id":"32318deb-2f3c-4386-bc87-6bc3349f7202","type":"BasicTickFormatter"},"plot":{"id":"b6a37996-39c0-4d76-b1b6-25e25c1ff6f1","subtype":"Chart","type":"Plot"},"ticker":{"id":"f24e4f4a-59c0-4bab-bb3f-0f64e9b7d816","type":"BasicTicker"}},"id":"e7b018d4-59be-4e79-b355-a6568f9eb074","type":"LinearAxis"},{"attributes":{},"id":"f24e4f4a-59c0-4bab-bb3f-0f64e9b7d816","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"b6a37996-39c0-4d76-b1b6-25e25c1ff6f1","subtype":"Chart","type":"Plot"},"ticker":{"id":"f24e4f4a-59c0-4bab-bb3f-0f64e9b7d816","type":"BasicTicker"}},"id":"4448f84e-7a3b-4654-b239-8b91329d34e0","type":"Grid"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"aa8ee8be-a517-4094-b679-20eb498fd54f","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":"CULTURAL AFFAIRS"}],"color":["green"],"fill_alpha":[0.8],"height":[38664.0],"index":["CULTURAL AFFAIRS"],"label":[{"index":"CULTURAL AFFAIRS"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["CULTURAL AFFAIRS"],"y":[19332.0]}},"id":"7efb1888-c63e-4217-a3b0-6efc7e41c442","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"7efb1888-c63e-4217-a3b0-6efc7e41c442","type":"ColumnDataSource"},"glyph":{"id":"5f43242c-ac12-4324-b0d6-978bd00cce85","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"d1726d09-dff1-4fa3-8782-a0f14cf220ac","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":"LANDMARKS PRESERVATION COMM"}],"color":["green"],"fill_alpha":[0.8],"height":[39000.0],"index":["LANDMARKS PRESERVATION COMM"],"label":[{"index":"LANDMARKS PRESERVATION COMM"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["LANDMARKS PRESERVATION COMM"],"y":[19500.0]}},"id":"cce34ce6-a60f-47cc-8c25-944ca04d6732","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"cce34ce6-a60f-47cc-8c25-944ca04d6732","type":"ColumnDataSource"},"glyph":{"id":"aa8ee8be-a517-4094-b679-20eb498fd54f","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1c3c7a8d-5a25-4760-8a30-c9d550ee3e76","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"index":"DISTRICT ATTORNEY KINGS COUNTY"}],"color":["green"],"fill_alpha":[0.8],"height":[41036.0],"index":["DISTRICT ATTORNEY KINGS COUNTY"],"label":[{"index":"DISTRICT ATTORNEY KINGS COUNTY"}],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["DISTRICT ATTORNEY KINGS COUNTY"],"y":[20518.0]}},"id":"d1d8b28a-ee99-4e69-ba20-6607da895611","type":"ColumnDataSource"},{"attributes":{"formatter":{"id":"e3af76dd-adac-4440-869a-cde3ac56d8f8","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"b6a37996-39c0-4d76-b1b6-25e25c1ff6f1","subtype":"Chart","type":"Plot"},"ticker":{"id":"f566ae7e-8db2-46a9-be99-98d3c3f6b1be","type":"CategoricalTicker"}},"id":"b2e31610-5e47-467e-8dab-9b33520fa661","type":"CategoricalAxis"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bd35ee6a-824b-4cde-a8c4-b83ba57a460e","type":"Rect"},{"attributes":{"data_source":{"id":"5c037e05-d577-437a-b3ec-8b95793cc086","type":"ColumnDataSour ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[12]</strong>&gt;</code></p>

# %% [markdown]
# # Top 10 Job Posting Counts

# %%
pos_count_viz = agency_pos_count.iloc[0:10]
y = list(pos_count_viz.index)
x = pos_count_viz.loc[:, '__of_positions']
max_x = pos_count_viz['__of_positions'].max()
source = ColumnDataSource(dict(x=list(y), y=list(x)))

p_count = figure(plot_width=500, plot_height=500, y_range=list(reversed(y)), x_range=(0, max_x+50))
p_count.title.text = 'Top 10 Job Postings Per NYC Agency'
p_count.title.text_color = 'black'
p_count.title.text_font = 'times'
p_count.title.text_font_style = 'bold'

p.yaxis.major_label_orientation = "horizontal"
p_count.yaxis.minor_tick_line_color = None
p_count.xaxis.axis_label = '# of Job Postings'
p_count.yaxis.axis_label = 'Agency'

labels = LabelSet(x='y', y='x', text='y', level='glyph', y_offset=-1, source=source, render_mode='canvas')

p_count.hbar(y=y, height=0.5, right=x, color="navy")
p_count.add_layout(labels)
output_file('NYC_Job_Count.html', mode='cdn')
show(p_count)
# Out:
# INFO:bokeh.core.state:Session output file 'NYC_Job_Count.html' already exists, will be overwritten.
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9edb2c2f-471f-44f5-9652-040b0057d506"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("9edb2c2f-471f-44f5-9652-040b0057d506").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9edb2c2f-471f-44f5-9652-040b0057d506");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9edb2c2f-471f-44f5-9652-040b0057d506' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8d82f6da-e90a-4d93-8181-4edafad72753":{"roots":{"references":[{"attributes":{"plot":{"id":"c3e3d904-2ac7-464c-add7-01da5822944f","subtype":"Figure","type":"Plot"}},"id":"71b9cbdc-e2ff-48ec-b40a-06b739e789c6","type":"HelpTool"},{"attributes":{"dimension":1,"plot":{"id":"c3e3d904-2ac7-464c-add7-01da5822944f","subtype":"Figure","type":"Plot"},"ticker":{"id":"67aa91d9-610b-4004-9af0-e78f62af2df7","type":"CategoricalTicker"}},"id":"ca2597a7-8112-4d99-abcd-93c39bffac40","type":"Grid"},{"attributes":{"plot":null,"text":"Top 10 Job Postings Per NYC Agency","text_color":{"value":"black"},"text_font":"times"},"id":"02a9f1db-b99d-4ecb-b3d4-497c248550ed","type":"Title"},{"attributes":{"plot":{"id":"c3e3d904-2ac7-464c-add7-01da5822944f","subtype":"Figure","type":"Plot"},"ticker":{"id":"2b314e11-cf10-493c-8b79-8a08d62024cb","type":"BasicTicker"}},"id":"37f66722-85e3-4558-b444-51b1ba114ffa","type":"Grid"},{"attributes":{"plot":{"id":"c3e3d904-2ac7-464c-add7-01da5822944f","subtype":"Figure","type":"Plot"}},"id":"4169175c-0c9e-4c19-8299-eaee0ff495a3","type":"WheelZoomTool"},{"attributes":{"callback":null,"factors":["DEPT OF PARKS & RECREATION","FIRE DEPARTMENT","LAW DEPARTMENT","DEPT OF DESIGN & CONSTRUCTION","POLICE DEPARTMENT","DEPT OF INFO TECH & TELECOMM","DEPARTMENT OF FINANCE","DEPARTMENT OF TRANSPORTATION","DEPT OF ENVIRONMENT PROTECTION","DEPT OF HEALTH/MENTAL HYGIENE"]},"id":"3e3a82b4-0df2-4d96-af05-4515db9159ad","type":"FactorRange"},{"attributes":{"level":"glyph","plot":{"id":"c3e3d904-2ac7-464c-add7-01da5822944f","subtype":"Figure","type":"Plot"},"source":{"id":"a61ceddd-07dd-422b-9b26-888c4fbee779","type":"ColumnDataSource"},"text":{"field":"y"},"x":{"field":"y"},"y":{"field":"x"},"y_offset":{"value":-1}},"id":"91697d71-3362-45cb-81f6-bd4890ec8a07","type":"LabelSet"},{"attributes":{"axis_label":"# of Job Postings","formatter":{"id":"0783afee-6564-4f07-91db-a1b948395af7","type":"BasicTickFormatter"},"plot":{"id":"c3e3d904-2ac7-464c-add7-01da5822944f","subtype":"Figure","type":"Plot"},"ticker":{"id":"2b314e11-cf10-493c-8b79-8a08d62024cb","type":"BasicTicker"}},"id":"1031c0fb-5ccd-4631-9b15-ee37fb059e99","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"value":0.5},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"y":{"field":"y"}},"id":"fb9c9cbf-82c2-4b96-885c-27add21486be","type":"HBar"},{"attributes":{},"id":"9d4d6738-1a7e-4080-8c86-19f83dc0a176","type":"CategoricalTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9c46821e-1f30-4832-a1a3-0ff34bc874eb","type":"PanTool"},{"id":"4169175c-0c9e-4c19-8299-eaee0ff495a3","type":"WheelZoomTool"},{"id":"130e72b0-a81d-4f01-9d43-e80cbfc9f0a8","type":"BoxZoomTool"},{"id":"2952673e-5045-4248-9b58-43ba5e973f79","type":"SaveTool"},{"id":"f102e7eb-f42a-4fc1-aad2-39ab30d757c9","type":"ResetTool"},{"id":"71b9cbdc-e2ff-48ec-b40a-06b739e789c6","type":"HelpTool"}]},"id":"22db4030-026e-4e97-8a67-47ea7ff9c889","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["y","right"],"data":{"right":[247,122,69,54,47,37,36,26,26,25],"y":["DEPT OF HEALTH/MENTAL HYGIENE","DEPT OF ENVIRONMENT PROTECTION","DEPARTMENT OF TRANSPORTATION","DEPARTMENT OF FINANCE","DEPT OF INFO TECH & TELECOMM","POLICE DEPARTMENT","DEPT OF DESIGN & CONSTRUCTION","LAW DEPARTMENT","FIRE DEPARTMENT","DEPT OF PARKS & RECREATION"]}},"id":"63232894-03f0-4697-802e-98da93590bf8","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"c3e3d904-2ac7-464c-add7-01da5822944f","subtype":"Figure","type":"Plot"}},"id":"f102e7eb-f42a-4fc1-aad2-39ab30d757c9","type":"ResetTool"},{"attributes":{"fill_color":{"value":"navy"},"height":{"value":0.5},"line_color":{"value":"navy"},"right":{"field":"right"},"y":{"field":"y"}},"id":"a74ea8a3-c844-40ea-afc3-3b7429f9f43c","type":"HBar"},{"attributes":{"plot":{"id":"c3e3d904-2ac7-464c-add7-01da5822944f","subtype":"Figure","t ...

# %%
'''

from bokeh.palettes import PuBu
from bokeh.io import show, output_notebook
from bokeh.models import ColumnDataSource, ranges, LabelSet
from bokeh.plotting import figure
output_notebook()

source = ColumnDataSource(dict(x=['Áætlaðir','Unnir'],y=[576,608]))

x_label = ""
y_label = "Tímar (klst)"
title = "Tímar; núllti til þriðji sprettur."
plot = figure(plot_width=600, plot_height=300, tools="save",
        x_axis_label = x_label,
        y_axis_label = y_label,
        title=title,
        x_minor_ticks=2,
        x_range = source.data["x"],
        y_range= ranges.Range1d(start=0,end=700))


labels = LabelSet(x='x', y='y', text='y', level='glyph',
        x_offset=-13.5, y_offset=0, source=source, render_mode='canvas')

plot.vbar(source=source,x='x',top='y',bottom=0,width=0.3,color=PuBu[7][2])

plot.add_layout(labels)
show(plot)

# Saving these for later as I'll need these
#p.xaxis[0].formatter = NumeralTickFormatter(format="0.0%")
#p.yaxis[0].formatter = NumeralTickFormatter(format="$0.00")
'''
# Out:
# 'from bokeh.palettes import PuBu\nfrom bokeh.io import show, output_notebook\nfrom bokeh.models import ColumnDataSource, ranges, LabelSet\nfrom bokeh.plotting import figure\noutput_notebook()\n\nsource = ColumnDataSource(dict(x=[\'Áætlaðir\',\'Unnir\'],y=[576,608]))\n\nx_label = ""\ny_label = "Tímar (klst)"\ntitle = "Tímar; núllti til þriðji sprettur."\nplot = figure(plot_width=600, plot_height=300, tools="save",\n        x_axis_label = x_label,\n        y_axis_label = y_label,\n        title=title,\n        x_minor_ticks=2,\n        x_range = source.data["x"],\n        y_range= ranges.Range1d(start=0,end=700))\n\n\nlabels = LabelSet(x=\'x\', y=\'y\', text=\'y\', level=\'glyph\',\n        x_offset=-13.5, y_offset=0, source=source, render_mode=\'canvas\')\n\nplot.vbar(source=source,x=\'x\',top=\'y\',bottom=0,width=0.3,color=PuBu[7][2])\n\nplot.add_layout(labels)\nshow(plot)'

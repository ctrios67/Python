# %%
import pandas as pd
import datetime as dt

today = dt.datetime.today().strftime("%m/%d/%Y %H:%M:%S")
NYC = pd.read_json('https://data.cityofnewyork.us/resource/swhp-yxa4.json')
#NYC.info()
# minimum_qual_requirements has nulls
# post_until has nulls too (a majority actually)
NYC['minimum_qual_requirements'].fillna('Not Applicable', inplace=True)
NYC['post_until'].fillna(today, inplace=True)
NYC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 25 columns):
# __of_positions               1000 non-null int64
# additional_information       1000 non-null object
# agency                       1000 non-null object
# business_title               1000 non-null object
# civil_service_title          1000 non-null object
# division_work_unit           1000 non-null object
# hours_shift                  1000 non-null object
# job_description              1000 non-null object
# job_id                       1000 non-null int64
# level                        1000 non-null object
# minimum_qual_requirements    1000 non-null object
# post_until                   1000 non-null object
# posting_date                 1000 non-null object
# posting_type                 1000 non-null object
# posting_updated              1000 non-null object
# preferred_skills             1000 non-null object
# process_date                 1000 non-null object
# residency_requirement        1000 non-null object
# salary_frequency             1000 non-null object
# salary_range_from            1000 non-null int64
# salary_range_to              1000 non-null int64
# title_code_no                1000 non-null object
# to_apply                     1000 non-null object
# work_location                1000 non-null object
# work_location_1              1000 non-null object
# dtypes: int64(4), object(21)
# memory usage: 203.1+ KB

# %%
# Get a Dataframe showing the Agency with the Most # of Positions
numOfJobs = pd.DataFrame(NYC, columns=['agency', '__of_positions'])
numOfJobs = numOfJobs.groupby('agency').count()
numOfJobs = numOfJobs.sort_values(by='__of_positions', ascending=False)
numOfJobs = numOfJobs.head(10)
numOfJobs
# Out:
#                                 __of_positions
# agency
# DEPT OF HEALTH/MENTAL HYGIENE              260
# DEPT OF ENVIRONMENT PROTECTION             139
# DEPARTMENT OF TRANSPORTATION                61
# DEPT OF INFO TECH & TELECOMM                53
# DEPARTMENT OF FINANCE                       45
# DEPT OF DESIGN & CONSTRUCTION               44
# POLICE DEPARTMENT                           28
# HOUSING PRESERVATION & DVLPMNT              26
# DEPT OF PARKS & RECREATION                  24
# ADMIN FOR CHILDREN'S SVCS                   23

# %%
# Get a Dataframe showing the Agency with the lowest pay available.
lowestPay = pd.DataFrame(NYC, columns=['agency', 'salary_range_from', 'salary_frequency'])
lowestPay['Consolidated Salaries'] = lowestPay['salary_range_from'].copy()
lowestPay['Consolidated Salaries'][ lowestPay['salary_frequency'] == 'Daily'] = \
lowestPay['Consolidated Salaries']*(52*5)
lowestPay['Consolidated Salaries'][ lowestPay['salary_frequency'] == 'Hourly'] = \
lowestPay['Consolidated Salaries']*(1820)
dfL = lowestPay[['agency', 'Consolidated Salaries']]
dfL = dfL.groupby(['agency']).min()
dfL = dfL.sort_values(by='Consolidated Salaries', ascending=True)
##lowestPay = lowestPay.groupby(['agency']).min()
##lowestPay = lowestPay.sort_values(by='Consolidated Salaries', ascending=True)
##lowestPay = lowestPay[['agency', 'Consolidated Salaries']]
dfL
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                 Consolidated Salaries
# agency
# DEPT OF HEALTH/MENTAL HYGIENE                   18200
# DEPARTMENT FOR THE AGING                        18200
# DEPT OF ENVIRONMENT PROTECTION                  18200
# DEPARTMENT OF FINANCE                           18200
# DEPARTMENT OF BUILDINGS                         20020
# ADMIN TRIALS AND HEARINGS                       21840
# TAX COMMISSION                                  21840
# POLICE DEPARTMENT                               21840
# DEPT OF PARKS & RECREATION                      21840
# DEPARTMENT OF BUSINESS SERV.                    21840
# TAXI & LIMOUSINE COMMISSION                     25480
# DEPARTMENT OF PROBATION                         25480
# DEPT OF YOUTH & COMM DEV SRVS                   25480
# HUMAN RIGHTS COMMISSION                         25480
# DEPT OF DESIGN & CONSTRUCTION                   27300
# DEPARTMENT OF TRANSPORTATION                    29842
# MAYORS OFFICE OF CONTRACT SVCS                  30000
# MANHATTAN COMMUNITY BOARD #10                   30273
# DEPARTMENT OF CORRECTION                        32221
# LAW DEPARTMENT                                  32850
# ADMIN FOR CHILDREN'S SVCS                       33875
# DEPARTMENT OF INVESTIGATION                     33875
# NYC HOUSING AUTHORITY                           35327
# HRA/DEPT OF SOCIAL SERVICES                     35683
# CIVILIAN COMPLAINT REVIEW BD                    35683
# DEPT OF INFO TECH & TELECOMM                    35683
# HOUSING PRESERVATION & DVLPMNT                  36412
# DEPARTMENT OF SANITATION                        39664
# CONFLICTS OF INTEREST BOARD                     41996
# DEPT OF CITYWIDE ADMIN SVCS                     42443
# OFF OF PAYROLL ADMINISTRATION                   46747
# DEPT. OF HOMELESS SERVICES                      47549
# FINANCIAL INFO SVCS AGENCY                      47692
# DISTRICT ATTORNEY RICHMOND COU                  47692
# CULTURAL AFFAIRS                                47833
# FIRE DEPARTMENT                                 48535
# NYC EMPLOYEES RETIREMENT SYS                    49748
# OFFICE OF EMERGENCY MANAGEMENT                  50000
# OFFICE OF THE COMPTROLLER                       50000
# PRESIDENT BOROUGH OF MANHATTAN                  50500
# TEACHERS RETIREMENT SYSTEM                      50750
# CONSUMER AFFAIRS                                54643
# DISTRICT ATTORNEY KINGS COUNTY                  58880
# DEPARTMENT OF CITY PLANNING                     63817
# EQUAL EMPLOY PRACTICES COMM                     73938

# %%
# Get the highest pay
highestPay = pd.DataFrame(NYC, columns=['agency', 'salary_range_to', 'salary_frequency'])
highestPay['Consolidated Salaries'] = highestPay['salary_range_to'].copy()
highestPay['Consolidated Salaries'][ highestPay['salary_frequency'] == 'Daily'] = \
highestPay['Consolidated Salaries']*(52*5)
highestPay['Consolidated Salaries'][ highestPay['salary_frequency'] == 'Hourly'] = \
highestPay['Consolidated Salaries']*(1820)
dfH = highestPay[['agency', 'Consolidated Salaries']]
dfH = dfH.groupby(['agency']).max()
dfH = dfH.sort_values(by='Consolidated Salaries', ascending=False)
##highestPay = highestPay.groupby(['agency']).max()
##highestPay = highestPay.sort_values(by='Consolidated Salaries', ascending=False)
##highestPay
dfH
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                 Consolidated Salaries
# agency
# CIVILIAN COMPLAINT REVIEW BD                   234738
# NYC EMPLOYEES RETIREMENT SYS                   225000
# DEPT OF HEALTH/MENTAL HYGIENE                  224749
# DEPT OF YOUTH & COMM DEV SRVS                  215942
# DEPT OF DESIGN & CONSTRUCTION                  208298
# DEPT OF INFO TECH & TELECOMM                   200000
# ADMIN FOR CHILDREN'S SVCS                      200000
# DEPT OF CITYWIDE ADMIN SVCS                    199000
# DEPT OF ENVIRONMENT PROTECTION                 198518
# DEPARTMENT OF TRANSPORTATION                   195000
# DEPARTMENT OF SANITATION                       194395
# DEPARTMENT OF INVESTIGATION                    190000
# HOUSING PRESERVATION & DVLPMNT                 185000
# FINANCIAL INFO SVCS AGENCY                     180000
# DEPARTMENT FOR THE AGING                       178873
# DEPARTMENT OF BUSINESS SERV.                   162014
# TAX COMMISSION                                 161497
# POLICE DEPARTMENT                              161497
# HRA/DEPT OF SOCIAL SERVICES                    156793
# HUMAN RIGHTS COMMISSION                        153750
# DEPARTMENT OF PROBATION                        150371
# CONSUMER AFFAIRS                               150371
# FIRE DEPARTMENT                                143780
# DEPARTMENT OF FINANCE                          140000
# LAW DEPARTMENT                                 138880
# ADMIN TRIALS AND HEARINGS                      130000
# DEPARTMENT OF CITY PLANNING                    130000
# DEPARTMENT OF CORRECTION                       130000
# MAYORS OFFICE OF CONTRACT SVCS                 125000
# OFFICE OF THE COMPTROLLER                      120000
# DEPARTMENT OF BUILDINGS                        120000
# CULTURAL AFFAIRS                               120000
# DEPT. OF HOMELESS SERVICES                     103332
# DEPT OF PARKS & RECREATION                     101148
# TAXI & LIMOUSINE COMMISSION                    100000
# NYC HOUSING AUTHORITY                           92249
# OFFICE OF EMERGENCY MANAGEMENT                  90000
# EQUAL EMPLOY PRACTICES COMM                     85029
# OFF OF PAYROLL ADMINISTRATION                   83000
# DISTRICT ATTORNEY KINGS COUNTY                  82462
# DISTRICT ATTORNEY RICHMOND COU                  75000
# TEACHERS RETIREMENT SYSTEM                      65000
# PRESIDENT BOROUGH OF MANHATTAN                  50500
# CONFLICTS OF INTEREST BOARD                     47000
# MANHATTAN COMMUNITY BOARD #10                   39275

# %%
#numOfJobs.plot.barh(title='# of Jobs per NYC Agency', figsize=(10,10));
#a = plt.show()
#a
import matplotlib.pyplot as plt
import numpy as np

plt.rcdefaults()
fig, ax = plt.subplots()

x_axis = tuple(numOfJobs.__of_positions)
y_axis = tuple(numOfJobs.index)

ax.bar(left = y_axis, height = x_axis, width = 0.8, bottom=None, align='center', color='green')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-2823c0a48ef1> in <module>()
#      11 y_axis = tuple(numOfJobs.index)
#      12
# ---> 13 ax.bar(left = y_axis, height = x_axis, width = 0.8, bottom=None, align='center', color='green')
#      14 plt.show()
#
# /usr/local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1890                     warnings.warn(msg % (label_namer, func.__name__),
#    1891                                   RuntimeWarning, stacklevel=2)
# -> 1892             return func(ax, *args, **kwargs)
#    1893         pre_doc = inner.__doc__
#    1894         if pre_doc is None:
#
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in bar(self, left, height, width, bottom, **kwargs)
#    2103         if align == 'center':
#    2104             if orientation == 'vertical':
# -> 2105                 left = [left[i] - width[i] / 2. for i in xrange(len(left))]
#    2106             elif orientation == 'horizontal':
#    2107                 bottom = [bottom[i] - height[i] / 2.
#
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in <listcomp>(.0)
#    2103         if align == 'center':
#    2104             if orientation == 'vertical':
# -> 2105                 left = [left[i] - width[i] / 2. for i in xrange(len(left))]
#    2106             elif orientation == 'horizontal':
#    2107                 bottom = [bottom[i] - height[i] / 2.
#
# TypeError: unsupported operand type(s) for -: 'str' and 'float'

# %%
dfL.plot.barh(title='Lowest Salaries Offered by NYC Agency', figsize=(10,10));
l = plt.show()
l

# %%
dfH.plot.barh(title='Lowest Salaries Offered by NYC Agency', figsize=(10,10));
h = plt.show()
h

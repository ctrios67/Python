# %%
import pandas as pd
import datetime as dt
import re

today = dt.datetime.today().strftime("%m/%d/%Y %H:%M:%S")
NYC = pd.read_json('https://data.cityofnewyork.us/resource/swhp-yxa4.json')
NYC = NYC.set_index('agency')
work_hours = re.compile(r'\w*\d\d\w*')

# %%
NYC.info()
NYC.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, DEPARTMENT OF INVESTIGATION to ADMIN FOR CHILDREN'S SVCS
# Data columns (total 24 columns):
# __of_positions               1000 non-null int64
# additional_information       1000 non-null object
# business_title               1000 non-null object
# civil_service_title          1000 non-null object
# division_work_unit           1000 non-null object
# hours_shift                  1000 non-null object
# job_description              1000 non-null object
# job_id                       1000 non-null int64
# level                        1000 non-null object
# minimum_qual_requirements    991 non-null object
# post_until                   295 non-null object
# posting_date                 1000 non-null object
# posting_type                 1000 non-null object
# posting_updated              1000 non-null object
# preferred_skills             1000 non-null object
# process_date                 1000 non-null object
# residency_requirement        1000 non-null object
# salary_frequency             1000 non-null object
# salary_range_from            1000 non-null int64
# salary_range_to              1000 non-null int64
# title_code_no                1000 non-null object
# to_apply                     1000 non-null object
# work_location                1000 non-null object
# work_location_1              1000 non-null object
# dtypes: int64(4), object(20)
# memory usage: 195.3+ KB
#                                 __of_positions  \
# agency
# DEPARTMENT OF INVESTIGATION                  1
# DEPT OF ENVIRONMENT PROTECTION               1
# DEPARTMENT OF BUSINESS SERV.                 1
#
#                                                            additional_information  \
# agency
# DEPARTMENT OF INVESTIGATION     Appointments are subject to Office of Manageme...
# DEPT OF ENVIRONMENT PROTECTION  DEP is an equal opportunity employer with a st...
# DEPARTMENT OF BUSINESS SERV.
#
#                                                            business_title  \
# agency
# DEPARTMENT OF INVESTIGATION                             INSPECTOR GENERAL
# DEPT OF ENVIRONMENT PROTECTION                    Water Resources Analyst
# DEPARTMENT OF BUSINESS SERV.    PROGRAM COORDINATOR, VENDOR SERVICES/PTAC
#
#                                            civil_service_title  \
# agency
# DEPARTMENT OF INVESTIGATION                  INSPECTOR GENERAL
# DEPT OF ENVIRONMENT PROTECTION         CITY RESEARCH SCIENTIST
# DEPARTMENT OF BUSINESS SERV.    BUSINESS PROMOTION COORDINATOR
#
#                                             division_work_unit hours_shift  \
# agency
# DEPARTMENT OF INVESTIGATION                            Default
# DEPT OF ENVIRONMENT PROTECTION  BEPA/MS4-Muni Sepa Strm Sew Sy
# DEPARTMENT OF BUSINESS SERV.              Defo Vendor Services
#
#                                                                   job_description  \
# agency
# DEPARTMENT OF INVESTIGATION     The New York City Department of Investigation ...
# DEPT OF ENVIRONMENT PROTECTION  The NYC Department of Environmental Protection...
# DEPARTMENT OF BUSINESS SERV.    Vendor Services / Procurement Technical Assist...
#
#                                 job_id level  \
# agency
# DEPARTMENT OF INVESTIGATION     277531    M4
# DEPT OF ENVIRONMENT PROTECTION  282497    02
# DEPARTMENT OF BUSINESS SERV.    283007    01
#
#                                                         minimum_qual_requirements  \
# agency
# DEPARTMENT OF INVESTIGATION     1. A baccalaureate degree from an accredited c...
# DEPT OF ENVIRONMENT PROTECTION  1.  For Assignment Level I (only physical, bio...
# DEPARTMENT OF BUSINESS SERV.    1. A masters degree from an accredited college...
#
#                                      ...         \
# agency                               ...
# DEPARTMENT OF INVESTIGATION          ...
# DEPT OF ENVIRONMENT PROTECTION       ...
# DEPARTMENT OF BUSINESS SERV.         ...
#
#                                                                  preferred_skills  \
# agency
# DEPARTMENT OF INVESTIGATION     1.\tJuris Doctor, Certified Public Accountant ...
# DEPT OF ENVIRONMENT PROTECTION  The ideal candidate will have demonstrated exp...
# DEPARTMENT OF BUSINESS SERV.    â€¢Advanced proficiency using MS Word, MS Exce...
#
#                                        process_date  \
# agency
# DEPARTMENT OF INVESTIGATION     04/11/2017 00:00:00
# DEPT OF ENVIRONMENT PROTECTION  04/11/2017 00:00:00
# DEPARTMENT OF BUSINESS SERV.    04/11/2017 00:00:00
#
#                                                             residency_requirement  \
# agency
# DEPARTMENT OF INVESTIGATION     There's no residency requirement for this posi...
# DEPT OF ENVIRONMENT PROTECTION  New York City residency is generally required ...
# DEPARTMENT OF BUSINESS SERV.    New York City residency is generally required ...
#
#                                salary_frequency salary_range_from  \
# agency
# DEPARTMENT OF INVESTIGATION              Annual            115000
# DEPT OF ENVIRONMENT PROTECTION           Annual             70286
# DEPARTMENT OF BUSINESS SERV.             Annual             39399
#
#                                salary_range_to title_code_no  \
# agency
# DEPARTMENT OF INVESTIGATION             160000         31145
# DEPT OF ENVIRONMENT PROTECTION           88213         21744
# DEPARTMENT OF BUSINESS SERV.             50000         60860
#
#                                                                          to_apply  \
# agency
# DEPARTMENT OF INVESTIGATION     All current City Employees may apply by going ...
# DEPT OF ENVIRONMENT PROTECTION                       To apply click ''Apply Now''
# DEPARTMENT OF BUSINESS SERV.    Please email your resume and cover letter incl...
#
#                                                 work_location  work_location_1
# agency
# DEPARTMENT OF INVESTIGATION      188 West 230 Street Bronx Ny            Bronx
# DEPT OF ENVIRONMENT PROTECTION  59-17 Junction Blvd Corona Ny
# DEPARTMENT OF BUSINESS SERV.              110 William St. N Y
#
# [3 rows x 24 columns]

# %% [markdown]
# # Cleaning the Data.

# %%
# Taking care of Nulls
NYC['minimum_qual_requirements'].fillna('Not Applicable', inplace=True)
NYC['post_until'].fillna(today, inplace=True)
NYC['post_until'] = pd.to_datetime(NYC['post_until'])
NYC['posting_date'] = pd.to_datetime(NYC['posting_date'])
NYC['process_date'] = pd.to_datetime(NYC['process_date'])


# There are "empty" columns still in the data, but not NULL, need to be taken care of.
NYC['additional_information'] # -> Some results are "empty", like in index 2
NYC['additional_information'][2] # -> is equal to ' '
add_info_mask = NYC['additional_information'] == ' '
NYC[add_info_mask] # 432 occurences of this
hours_shift_mask = NYC['hours_shift'] == ' '
NYC[hours_shift_mask] # 684 occurences
pref_skill_mask = NYC['preferred_skills'] == ' ' # 118 occurences
work_loc_1_mask = NYC['work_location_1'] == ' ' # 520 occurences
mask = [add_info_mask, hours_shift_mask, pref_skill_mask, work_loc_1_mask]

# Replace Nulls that we as viewer see, but that Pandas is unaware about.
NYC['additional_information'] = NYC['additional_information'].replace(to_replace=' ', value='Not Available.')
NYC['hours_shift'] = NYC['hours_shift'].replace(to_replace=' ', value='Not Available.')
NYC['preferred_skills'] = NYC['preferred_skills'].replace(to_replace=' ', value='Not Available.')
NYC['work_location_1'] = NYC['work_location_1'].replace(to_replace=' ', value='Not Available.')
NYC

# Seeing which objects I put as categorize as dtype category to conserve space/efficiency.
unique = {}
for col in NYC.columns:
    unique[col] = NYC[col].nunique()
#print(unique)

# Applying what I noticed from previous cell.
#NYC['agency'] = NYC['agency'].astype('category')
NYC['level'] = NYC['level'].astype('category')
NYC['posting_type'] = NYC['posting_type'].astype('category')
NYC['salary_frequency'] = NYC['salary_frequency'].astype('category')

# Sort by index
NYC.sort_index(inplace=True)

# memory usage shrunk from 203.1 KB -> 175 KB, 14%
NYC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, ADMIN FOR CHILDREN'S SVCS to TEACHERS RETIREMENT SYSTEM
# Data columns (total 24 columns):
# __of_positions               1000 non-null int64
# additional_information       1000 non-null object
# business_title               1000 non-null object
# civil_service_title          1000 non-null object
# division_work_unit           1000 non-null object
# hours_shift                  1000 non-null object
# job_description              1000 non-null object
# job_id                       1000 non-null int64
# level                        1000 non-null category
# minimum_qual_requirements    1000 non-null object
# post_until                   1000 non-null datetime64[ns]
# posting_date                 1000 non-null datetime64[ns]
# posting_type                 1000 non-null category
# posting_updated              1000 non-null object
# preferred_skills             1000 non-null object
# process_date                 1000 non-null datetime64[ns]
# residency_requirement        1000 non-null object
# salary_frequency             1000 non-null category
# salary_range_from            1000 non-null int64
# salary_range_to              1000 non-null int64
# title_code_no                1000 non-null object
# to_apply                     1000 non-null object
# work_location                1000 non-null object
# work_location_1              1000 non-null object
# dtypes: category(3), datetime64[ns](3), int64(4), object(14)
# memory usage: 175.0+ KB

# %% [markdown]
# # Data Analysis

# %%
NYC.head()
# Out:
#                            __of_positions  \
# agency
# ADMIN FOR CHILDREN'S SVCS               1
# ADMIN FOR CHILDREN'S SVCS               4
# ADMIN FOR CHILDREN'S SVCS               5
# ADMIN FOR CHILDREN'S SVCS               1
# ADMIN FOR CHILDREN'S SVCS               1
#
#                                                       additional_information  \
# agency
# ADMIN FOR CHILDREN'S SVCS  Section 424-A of the New York Social Services ...
# ADMIN FOR CHILDREN'S SVCS  Section 424-A of the New York Social Services ...
# ADMIN FOR CHILDREN'S SVCS  Section 424-A of the New York Social Services ...
# ADMIN FOR CHILDREN'S SVCS  Section 424-A of the New York Social Services ...
# ADMIN FOR CHILDREN'S SVCS  Section 424-A of the New York Social Services ...
#
#                                       business_title  \
# agency
# ADMIN FOR CHILDREN'S SVCS    Agency Medical Director
# ADMIN FOR CHILDREN'S SVCS               Case Analyst
# ADMIN FOR CHILDREN'S SVCS         Operations Manager
# ADMIN FOR CHILDREN'S SVCS                Audit Nurse
# ADMIN FOR CHILDREN'S SVCS  Pre-Placement Staff Nurse
#
#                                       civil_service_title  \
# agency
# ADMIN FOR CHILDREN'S SVCS           CITY MEDICAL DIRECTOR
# ADMIN FOR CHILDREN'S SVCS  CHILD WELFARE SPECIALIST SUPER
# ADMIN FOR CHILDREN'S SVCS  DEPUTY SUPERINTENDENT (JUVENIL
# ADMIN FOR CHILDREN'S SVCS            SUPERVISOR OF NURSES
# ADMIN FOR CHILDREN'S SVCS                     STAFF NURSE
#
#                                        division_work_unit     hours_shift  \
# agency
# ADMIN FOR CHILDREN'S SVCS  Office Of Chld & Fmly Hlth-Fss  Not Available.
# ADMIN FOR CHILDREN'S SVCS        Quality Improvement (Qa)  Not Available.
# ADMIN FOR CHILDREN'S SVCS         Horizon Juvenile Center  Not Available.
# ADMIN FOR CHILDREN'S SVCS  Office Of Chld & Fmly Hlth-Fss  Not Available.
# ADMIN FOR CHILDREN'S SVCS  Office Of Chld & Fmly Hlth-Fss  Not Available.
#
#                                                              job_description  \
# agency
# ADMIN FOR CHILDREN'S SVCS  The Office of Child and Family Health is seeki...
# ADMIN FOR CHILDREN'S SVCS  The 4 Case Analysts will be responsible for ev...
# ADMIN FOR CHILDREN'S SVCS  The Operations Manager is responsible for the ...
# ADMIN FOR CHILDREN'S SVCS  The Administration for Childrenâ€™s Services (...
# ADMIN FOR CHILDREN'S SVCS  The Administration for Childrenâ€™s Services (...
#
#                            job_id level  \
# agency
# ADMIN FOR CHILDREN'S SVCS  269622    M7
# ADMIN FOR CHILDREN'S SVCS  272617    02
# ADMIN FOR CHILDREN'S SVCS  261759    M1
# ADMIN FOR CHILDREN'S SVCS  239558    01
# ADMIN FOR CHILDREN'S SVCS  265912    00
#
#                                                    minimum_qual_requirements  \
# agency
# ADMIN FOR CHILDREN'S SVCS  1. Possession of a valid license to practice m...
# ADMIN FOR CHILDREN'S SVCS  1. A baccalaureate degree from an accredited c...
# ADMIN FOR CHILDREN'S SVCS                                     Not Applicable
# ADMIN FOR CHILDREN'S SVCS  A valid New York State License and current reg...
# ADMIN FOR CHILDREN'S SVCS  1. A valid New York State Registered Nurse Lic...
#
#                                                  ...                          \
# agency                                           ...
# ADMIN FOR CHILDREN'S SVCS                        ...
# ADMIN FOR CHILDREN'S SVCS                        ...
# ADMIN FOR CHILDREN'S SVCS                        ...
# ADMIN FOR CHILDREN'S SVCS                        ...
# ADMIN FOR CHILDREN'S SVCS                        ...
#
#                                                             preferred_skills  \
# agency
# ADMIN FOR CHILDREN'S SVCS  The preferred candidate should possess the fol...
# ADMIN FOR CHILDREN'S SVCS  The preferred candidate should possess the fol...
# ADMIN FOR CHILDREN'S SVCS  The preferred candidate should possess the fol...
# ADMIN FOR CHILDREN'S SVCS  A valid New York State License and current reg...
# ADMIN FOR CHILDREN'S SVCS  The preferred candidate should possess the fol...
#
#                           process_date  \
# agency
# ADMIN FOR CHILDREN'S SVCS   2017-04-11
# ADMIN FOR CHILDREN'S SVCS   2017-04-11
# ADMIN FOR CHILDREN'S SVCS   2017-04-11
# ADMIN FOR CHILDREN'S SVCS   2017-04-11
# ADMIN FOR CHILDREN'S SVCS   2017-04-11
#
#                                                        residency_requirement  \
# agency
# ADMIN FOR CHILDREN'S SVCS  New York City Residency is not required for th...
# ADMIN FOR CHILDREN'S SVCS  New York City Residency is not required for th...
# ADMIN FOR CHILDREN'S SVCS  New York City residency is generally required ...
# ADMIN FOR CHILDREN'S SVCS  New York City residency is generally required ...
# ADMIN FOR CHILDREN'S SVCS  New York City residency is generally required ...
#
#                           salary_frequency salary_range_from salary_range_to  \
# agency
# ADMIN FOR CHILDREN'S SVCS           Annual             99353          200000
# ADMIN FOR CHILDREN'S SVCS           Annual             75520           76674
# ADMIN FOR CHILDREN'S SVCS           Annual             73555           73555
# ADMIN FOR CHILDREN'S SVCS           Annual             76597           76597
# ADMIN FOR CHILDREN'S SVCS           Annual             71669           71669
#
#                           title_code_no                             to_apply  \
# agency
# ADMIN FOR CHILDREN'S SVCS         53047      Click the ''Apply Now'' Button.
# ADMIN FOR CHILDREN'S SVCS         52370   Click on the ''Apply Now'' Button.
# ADMIN FOR CHILDREN'S SVCS         51587   Click on the ''Apply Now'' button.
# ADMIN FOR CHILDREN'S SVCS         50960  Click on the ''Apply  Now'' Button.
# ADMIN FOR CHILDREN'S SVCS         50910    Click on the ''Apply Now'' Button
#
#                                             work_location  \
# agency
# ADMIN FOR CHILDREN'S SVCS  150 William Street, New York N
# ADMIN FOR CHILDREN'S SVCS  150 William Street, New York N
# ADMIN FOR CHILDREN'S SVCS  560 Brook Avenue Bronx New Yor
# ADMIN FOR CHILDREN'S SVCS  492 First Avenue, New York, Ny
# ADMIN FOR CHILDREN'S SVCS  492 First Avenue, New York, Ny
#
#                                                              work_location_1
# agency
# ADMIN FOR CHILDREN'S SVCS                                     Not Available.
# ADMIN FOR CHILDREN'S SVCS                                     Not Available.
# ADMIN FOR CHILDREN'S SVCS  560 Brook Avenue, Bronx 17 Bristol Street, Bro...
# ADMIN FOR CHILDREN'S SVCS                                     Not Available.
# ADMIN FOR CHILDREN'S SVCS                                     Not Available.
#
# [5 rows x 24 columns]

# %%
import pandas as pd
import datetime as dt

today = dt.datetime.today().strftime("%m/%d/%Y %H:%M:%S")
NYC = pd.read_json('https://data.cityofnewyork.us/resource/swhp-yxa4.json')
#NYC.info()
# minimum_qual_requirements has nulls
# post_until has nulls too (a majority actually)
NYC['minimum_qual_requirements'].fillna('Not Applicable', inplace=True)
NYC['post_until'].fillna(today, inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 25 columns):
# __of_positions               1000 non-null int64
# additional_information       1000 non-null object
# agency                       1000 non-null object
# business_title               1000 non-null object
# civil_service_title          1000 non-null object
# division_work_unit           1000 non-null object
# hours_shift                  1000 non-null object
# job_description              1000 non-null object
# job_id                       1000 non-null int64
# level                        1000 non-null object
# minimum_qual_requirements    1000 non-null object
# post_until                   1000 non-null object
# posting_date                 1000 non-null object
# posting_type                 1000 non-null object
# posting_updated              1000 non-null object
# preferred_skills             1000 non-null object
# process_date                 1000 non-null object
# residency_requirement        1000 non-null object
# salary_frequency             1000 non-null object
# salary_range_from            1000 non-null int64
# salary_range_to              1000 non-null int64
# title_code_no                1000 non-null object
# to_apply                     1000 non-null object
# work_location                1000 non-null object
# work_location_1              1000 non-null object
# dtypes: int64(4), object(21)
# memory usage: 203.1+ KB

# %%
NYC.head()
# Out:
#    __of_positions                             additional_information  \
# 0               1  Appointments are subject to Office of Manageme...
# 1               1  DEP is an equal opportunity employer with a st...
# 2               1
# 3               6  License Requirements For appointment to certai...
# 4               1  Please note:  If you are called for an intervi...
#
#                            agency  \
# 0     DEPARTMENT OF INVESTIGATION
# 1  DEPT OF ENVIRONMENT PROTECTION
# 2    DEPARTMENT OF BUSINESS SERV.
# 3        DEPARTMENT OF CORRECTION
# 4   DEPT OF HEALTH/MENTAL HYGIENE
#
#                                       business_title  \
# 0                                  INSPECTOR GENERAL
# 1                            Water Resources Analyst
# 2          PROGRAM COORDINATOR, VENDOR SERVICES/PTAC
# 3                                        Electrician
# 4  PECO Exercises and Training Coordinator, Burea...
#
#               civil_service_title              division_work_unit hours_shift  \
# 0               INSPECTOR GENERAL                         Default
# 1         CITY RESEARCH SCIENTIST  BEPA/MS4-Muni Sepa Strm Sew Sy
# 2  BUSINESS PROMOTION COORDINATOR            Defo Vendor Services
# 3                     ELECTRICIAN               F.M.R.D. Civilian
# 4           COMMUNITY COORDINATOR  Agency Preparedness & Response
#
#                                      job_description  job_id level  \
# 0  The New York City Department of Investigation ...  277531    M4
# 1  The NYC Department of Environmental Protection...  282497    02
# 2  Vendor Services / Procurement Technical Assist...  283007    01
# 3  The New York City Department of Correction (DO...  250903    00
# 4  NYC Department of Health and Mental Hygiene(NY...  273326    00
#
#         ...                                          preferred_skills  \
# 0       ...         1.\tJuris Doctor, Certified Public Accountant ...
# 1       ...         The ideal candidate will have demonstrated exp...
# 2       ...         â€¢Advanced proficiency using MS Word, MS Exce...
# 3       ...
# 4       ...         --Be familiar with and understand the Federal ...
#
#           process_date                              residency_requirement  \
# 0  04/11/2017 00:00:00  There's no residency requirement for this posi...
# 1  04/11/2017 00:00:00  New York City residency is generally required ...
# 2  04/11/2017 00:00:00  New York City residency is generally required ...
# 3  04/11/2017 00:00:00  New York City residency is generally required ...
# 4  04/11/2017 00:00:00  New York City residency is generally required ...
#
#   salary_frequency salary_range_from salary_range_to title_code_no  \
# 0           Annual            115000          160000         31145
# 1           Annual             70286           88213         21744
# 2           Annual             39399           50000         60860
# 3            Daily               343             343         91717
# 4           Annual             50362           78177         56058
#
#                                             to_apply  \
# 0  All current City Employees may apply by going ...
# 1                       To apply click ''Apply Now''
# 2  Please email your resume and cover letter incl...
# 3  For City employees: Go to Employee Self-Servic...
# 4  Apply online with a cover letter to https://a1...
#
#                     work_location  work_location_1
# 0    188 West 230 Street Bronx Ny            Bronx
# 1   59-17 Junction Blvd Corona Ny
# 2             110 William St. N Y
# 3  Hazen St-Sod-Supp.Svcs., E.Elm
# 4               42-09 28th Street
#
# [5 rows x 25 columns]

# %% [markdown]
# # Cleaning the Data.

# %%
# There are "empty" columns still in the data, but not NULL, need to be taken care of.
NYC['additional_information'] # -> Some results are "empty", like in index 2
NYC['additional_information'][2] # -> is equal to ' '
# Out:
# ' '
